# %%
from src.recommender import *
n = 20
# Out:
# ---------------------------------------------------------------------------
# SpotifyOauthError                         Traceback (most recent call last)
# <ipython-input-1-d7f04693471c> in <module>
# ----> 1 from src.recommender import *
#       2 n = 20
#
# ~/Documents/GitHub/And_Vinyly-a-Music-Reccomendation-System/src/recommender.py in <module>
#       1 from sklearn.metrics.pairwise import cosine_distances, cosine_similarity, euclidean_distances, pairwise_distances
#       2 from sklearn.preprocessing import StandardScaler
# ----> 3 from src.get_data import *
#       4 from sklearn.cluster import KMeans
#       5 from sklearn.pipeline import Pipeline
#
# ~/Documents/GitHub/And_Vinyly-a-Music-Reccomendation-System/src/get_data.py in <module>
#      12
#      13 # Setup Authentication
# ---> 14 auth_manager = SpotifyClientCredentials()
#      15 sp = spotipy.Spotify(auth_manager=auth_manager, requests_timeout=20,
#      16                     retries=20, status_retries=20, backoff_factor=3)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/spotipy/oauth2.py in __init__(self, client_id, client_secret, proxies, requests_session, requests_timeout, cache_handler)
#     177         super(SpotifyClientCredentials, self).__init__(requests_session)
#     178
# --> 179         self.client_id = client_id
#     180         self.client_secret = client_secret
#     181         self.proxies = proxies
#
# ~/opt/anaconda3/lib/python3.8/site-packages/spotipy/oauth2.py in client_id(self, val)
#      92     @client_id.setter
#      93     def client_id(self, val):
# ---> 94         self._client_id = _ensure_value(val, "client_id")
#      95
#      96     @property
#
# ~/opt/anaconda3/lib/python3.8/site-packages/spotipy/oauth2.py in _ensure_value(value, env_key)
#      68             env_val,
#      69         )
# ---> 70         raise SpotifyOauthError(msg)
#      71     return _val
#      72
#
# SpotifyOauthError: No client_id. Pass it or set a SPOTIPY_CLIENT_ID environment variable.

# %%
print(f'My shape is {df_mine.shape}', '\n')
print(f'Rolling shape is {df_rolling.shape}', '\n')
print(f'Mega_Mains shape is {df_mega_main.shape}', '\n')
# Out:
# My shape is (1109, 36)
#
# Rolling shape is (1363, 620)
#
# Mega_Mains shape is (22472, 27)

# %%
test_rec = ItemRecommender()
test_rec.fit(df_mega_main);

# %%
n = 12
recs = test_rec.get_recommendations('ghostwriter', 'rjd2', n=n)
# Out:
# You chose Ghostwriter by RJD2 for your song
# The most similar 12 songs are displayed below:
#  Artist Recommendation: RJD2
# Meanwhile, while you're waiting for the new RJD2 album, you can try one of your own albums below:
# And if you're looking to purchase a new record for the collection, here are some good options:
