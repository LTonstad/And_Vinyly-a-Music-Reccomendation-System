# %%
from src.recommender import *

# %%
df_mega_main = pd.read_pickle('../num_mega_main.pkl')

# %%
rec = ItemRecommender()
rec.fit(df_mega_main)
# Out:
#                             0         1         2         3         4    \
# Wesley's Theory        0.419042  1.516157  1.414560 -1.339147  0.075550
# For Free? - Interlude  0.419042  1.516157  1.414560 -1.118239  0.075550
# King Kunta             0.419042  1.516157  1.414560 -0.897330  0.075550
# Institutionalized      0.419042  1.516157  1.414560 -0.676421  0.075550
# These Walls            0.419042  1.516157  1.414560 -0.455513  0.075550
# ...                         ...       ...       ...       ...       ...
# Loud Pipes            -0.355882  0.236477 -0.392031 -0.234604 -0.461131
# Kennedy               -0.355882  0.236477 -0.392031 -0.013695 -0.461131
# Swisha                -0.355882  0.236477 -0.392031  0.207213 -0.461131
# Nostrand              -0.355882  0.236477 -0.392031  0.428122 -0.461131
# Tacobel Canon         -0.355882  0.236477 -0.392031  0.649031 -0.461131
#
#                             5         6         7         8         9    ...  \
# ...

# %%
rec.get_recommendations('ooh la la', 'run the jewels')
# Out:
# /home/luke/galvanize/capstones/DSI_Capstone_Three/src/data_prep.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[genre][i] = 1
# You chose ooh la la (feat. Greg Nice & DJ Premier) for your song
#  Number 1 pick:
#
#
#  Song chosen: I Am Easy To Find
#  Performed by: The National
#  On the Album: I Am Easy to Find
#  Number 2 pick:
#
#
#  Song chosen: Shutdown
#  Performed by: Skepta
#  On the Album: Konnichiwa
#  Number 3 pick:
#
#
#  Song chosen: By the Throat
#  Performed by: CHVRCHES
#  On the Album: The Bones of What You Believe
#  Number 4 pick:
#
#
#  Song chosen: Smother
#  Performed by: Daughter
#  On the Album: If You Leave
#  Number 5 pick:
#
#
#  Song chosen: How I Got Over
#  Performed by: The Roots
#  On the Album: How I Got Over
# ...
