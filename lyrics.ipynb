# %%
from src.lyrics_functions import *

# %%
albums = pd.read_pickle('../final_full_mine.pkl')
albums
# Out:
#                                                                                                                                                                                                                                           year  \
# album                       name                                               artist          release_date album_image_url                                    artist_image_url                                   id
# The Saga Continues          Wu-Tang The Saga Continues Intro (feat. RZA)       Wu-Tang Clan    2017-10-13   https://i.scdn.co/image/ab67616d0000b2730801dc9... https://i.scdn.co/image/c4014e4323f08d1a32d63c6... 2EsC5nxXhoMrOsYbt59VUM  2017
#                             Lesson Learn'd (feat. Inspectah Deck and Redman)   Wu-Tang Clan    2017-10-13   https://i.scdn.co/image/ab67616d0000b2730801dc9... https://i.scdn.co/image/c4014e4323f08d1a32d63c6... 2RQ47bAanXMoCKIIUn5Kxn  2017
# ...

# %%
lyrs = loop_songs_for_lyrics(albums)
# Out:
# Searching for "Wu-Tang The Saga Continues Intro (feat. RZA)" by Wu-Tang Clan...
# No results found for: 'Wu-Tang The Saga Continues Intro (feat. RZA) Wu-Tang Clan'
# Unable to find Wu-Tang The Saga Continues Intro (feat. RZA) on Genius search...
# Searching for "Lesson Learn'd (feat. Inspectah Deck and Redman)" by Wu-Tang Clan...
# Done.
# Searching for "Fast and Furious (feat. Hue Hef and Raekwon)" by Wu-Tang Clan...
# No results found for: 'Fast and Furious (feat. Hue Hef and Raekwon) Wu-Tang Clan'
# Unable to find Fast and Furious (feat. Hue Hef and Raekwon) on Genius search...
# Searching for "Famous Fighters (Skit)" by Wu-Tang Clan...
# Done.
# Searching for "If Time Is Money (Fly Navigation) [feat. Method Man]" by Wu-Tang Clan...
# No results found for: 'If Time Is Money (Fly Navigation) [feat. Method Man] Wu-Tang Clan'
# Unable to find If Time Is Money (Fly Navigation) [feat. Method Man] on Genius search...
# ...

# %%
lyrs
# Out:
# 0    no lyrics found
# dtype: object
