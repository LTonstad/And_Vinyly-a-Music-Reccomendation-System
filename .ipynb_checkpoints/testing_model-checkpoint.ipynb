# %%
from src.recommender import *

# %%
rec = ItemRecommender()
rec.fit(df_mega_main)

# %%
rec.get_recommendations('exile', 'taylor swift')

# %%
test_rec = ItemRecommender()
test_rec.fit(df_mega_main, no_genre=True)

# %%
test_rec.get_recommendations('ooh la la', 'run the jewels', no_genre=True)

# %%
df = pd.read_csv('../my_albums.csv')
df.columns
# Out:
# Index(['name', 'album', 'year', 'artist', 'featured_artists', 'track_number',
#        'tracks_on_album', 'explicit', 'duration_ms', 'popularity',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'type', 'id', 'uri', 'track_href', 'analysis_url', 'time_signature',
#        'artist_uri', 'album_uri', 'release_date', 'album_image_url',
#        'track_length', 'tempo_confidence', 'end_fade_in', 'start_fade_out',
#        'end_silence_time', 'sections', 'tatums', 'beats', 'bars'],
#       dtype='object')

# %%
df_mine.head(3)
# Out:
#                                                                                                                                                                          year  \
# album              name                                             artist       release_date album_image_url                                    id
# The Saga Continues Wu-Tang The Saga Continues Intro (feat. RZA)     Wu-Tang Clan 2017-10-13   https://i.scdn.co/image/ab67616d0000b2730801dc9... 2EsC5nxXhoMrOsYbt59VUM  2017
#                    Lesson Learn'd (feat. Inspectah Deck and Redman) Wu-Tang Clan 2017-10-13   https://i.scdn.co/image/ab67616d0000b2730801dc9... 2RQ47bAanXMoCKIIUn5Kxn  2017
#                    Fast and Furious (feat. Hue Hef and Raekwon)     Wu-Tang Clan 2017-10-13   https://i.scdn.co/image/ab67616d0000b2730801dc9... 2B6lQV5InRy13vd7wl26jg  2017
#
# ...

# %%
albums = pd.read_excel('data/my_albums.ods')
albums.head(3)
# Out:
#                 Title        Artist                    Label  Rating  \
# 0  The Saga Continues  Wu-Tang Clan   36 Chambers, eOne, SPV       3
# 1  Bon Iver, Bon Iver      Bon Iver          4AD, Jagjaguwar       5
# 2     The Eminem Show        Eminem  Aftermath Entertainment       4
#
#    Released  release_id    CollectionFolder           Date Added
# 0      2017    11042358         lyric-heavy  2018-01-05 01:01:24
# 1      2011     2942482  instrumental-heavy  2018-01-05 00:47:43
# 2      2002     1734171         lyric-heavy  2018-01-05 00:51:37
