# %%
from src.recommender import *
n = 20

# %%
df_mega_main.head(3)
# Out:
#                                                                                                                                                                                                     year  \
# album               name                  artist         release_date album_image_url                                    artist_image_url                                   id
# To Pimp A Butterfly Wesley's Theory       Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 7Ks4VCY1wFebnOdJrM13t6  2015
#                     For Free? - Interlude Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 75izAeHlGuOgA865CFDyIv  2015
#                     King Kunta            Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 0N3W5peJUQtI4eyR6GJT5O  2015
#
#                                                                                                                                                                                                     artist_popularity  \
# album               name                  artist         release_date album_image_url                                    artist_image_url                                   id
# To Pimp A Butterfly Wesley's Theory       Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 7Ks4VCY1wFebnOdJrM13t6                 89
#                     For Free? - Interlude Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 75izAeHlGuOgA865CFDyIv                 89
#                     King Kunta            Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 0N3W5peJUQtI4eyR6GJT5O                 89
#
#                                                                                                                                                                                                     followers  \
# album               name                  artist         release_date album_image_url                                    artist_image_url                                   id
# To Pimp A Butterfly Wesley's Theory       Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 7Ks4VCY1wFebnOdJrM13t6   17080939
#                     For Free? - Interlude Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 75izAeHlGuOgA865CFDyIv   17080939
#                     King Kunta            Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 0N3W5peJUQtI4eyR6GJT5O   17080939
#
#                                                                                                                                                                                                     track_number  \
# album               name                  artist         release_date album_image_url                                    artist_image_url                                   id
# To Pimp A Butterfly Wesley's Theory       Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 7Ks4VCY1wFebnOdJrM13t6             1
#                     For Free? - Interlude Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 75izAeHlGuOgA865CFDyIv             2
#                     King Kunta            Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 0N3W5peJUQtI4eyR6GJT5O             3
#
#                                                                                                                                                                                                     tracks_on_album  \
# album               name                  artist         release_date album_image_url                                    artist_image_url                                   id
# To Pimp A Butterfly Wesley's Theory       Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 7Ks4VCY1wFebnOdJrM13t6               16
#                     For Free? - Interlude Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 75izAeHlGuOgA865CFDyIv               16
#                     King Kunta            Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 0N3W5peJUQtI4eyR6GJT5O               16
#
#                                                                                                                                                                                                     explicit  \
# album               name                  artist         release_date album_image_url                                    artist_image_url                                   id
# To Pimp A Butterfly Wesley's Theory       Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 7Ks4VCY1wFebnOdJrM13t6         1
#                     For Free? - Interlude Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 75izAeHlGuOgA865CFDyIv         1
#                     King Kunta            Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 0N3W5peJUQtI4eyR6GJT5O         1
#
#                                                                                                                                                                                                     popularity  \
# album               name                  artist         release_date album_image_url                                    artist_image_url                                   id
# To Pimp A Butterfly Wesley's Theory       Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 7Ks4VCY1wFebnOdJrM13t6          63
#                     For Free? - Interlude Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 75izAeHlGuOgA865CFDyIv          57
#                     King Kunta            Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 0N3W5peJUQtI4eyR6GJT5O          74
#
#                                                                                                                                                                                                     danceability  \
# album               name                  artist         release_date album_image_url                                    artist_image_url                                   id
# To Pimp A Butterfly Wesley's Theory       Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 7Ks4VCY1wFebnOdJrM13t6         0.509
#                     For Free? - Interlude Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 75izAeHlGuOgA865CFDyIv         0.526
#                     King Kunta            Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 0N3W5peJUQtI4eyR6GJT5O         0.884
#
#                                                                                                                                                                                                     energy  \
# album               name                  artist         release_date album_image_url                                    artist_image_url                                   id
# To Pimp A Butterfly Wesley's Theory       Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 7Ks4VCY1wFebnOdJrM13t6   0.787
#                     For Free? - Interlude Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 75izAeHlGuOgA865CFDyIv   0.896
#                     King Kunta            Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 0N3W5peJUQtI4eyR6GJT5O   0.657
#
#                                                                                                                                                                                                     key  \
# album               name                  artist         release_date album_image_url                                    artist_image_url                                   id
# To Pimp A Butterfly Wesley's Theory       Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 7Ks4VCY1wFebnOdJrM13t6    7
#                     For Free? - Interlude Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 75izAeHlGuOgA865CFDyIv    8
#                     King Kunta            Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 0N3W5peJUQtI4eyR6GJT5O    6
#
#                                                                                                                                                                                                     ...  \
# album               name                  artist         release_date album_image_url                                    artist_image_url                                   id                      ...
# To Pimp A Butterfly Wesley's Theory       Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 7Ks4VCY1wFebnOdJrM13t6  ...
#                     For Free? - Interlude Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 75izAeHlGuOgA865CFDyIv  ...
#                     King Kunta            Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 0N3W5peJUQtI4eyR6GJT5O  ...
#
#                                                                                                                                                                                                     wisconsin indie  \
# album               name                  artist         release_date album_image_url                                    artist_image_url                                   id
# To Pimp A Butterfly Wesley's Theory       Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 7Ks4VCY1wFebnOdJrM13t6              0.0
#                     For Free? - Interlude Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 75izAeHlGuOgA865CFDyIv              0.0
#                     King Kunta            Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 0N3W5peJUQtI4eyR6GJT5O              0.0
#
#                                                                                                                                                                                                     wonky  \
# album               name                  artist         release_date album_image_url                                    artist_image_url                                   id
# To Pimp A Butterfly Wesley's Theory       Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 7Ks4VCY1wFebnOdJrM13t6    0.0
#                     For Free? - Interlude Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 75izAeHlGuOgA865CFDyIv    0.0
#                     King Kunta            Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 0N3W5peJUQtI4eyR6GJT5O    0.0
#
#                                                                                                                                                                                                     worcester ma indie  \
# album               name                  artist         release_date album_image_url                                    artist_image_url                                   id
# To Pimp A Butterfly Wesley's Theory       Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 7Ks4VCY1wFebnOdJrM13t6                 0.0
#                     For Free? - Interlude Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 75izAeHlGuOgA865CFDyIv                 0.0
#                     King Kunta            Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 0N3W5peJUQtI4eyR6GJT5O                 0.0
#
#                                                                                                                                                                                                     yacht rock  \
# album               name                  artist         release_date album_image_url                                    artist_image_url                                   id
# To Pimp A Butterfly Wesley's Theory       Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 7Ks4VCY1wFebnOdJrM13t6         0.0
#                     For Free? - Interlude Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 75izAeHlGuOgA865CFDyIv         0.0
#                     King Kunta            Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 0N3W5peJUQtI4eyR6GJT5O         0.0
#
#                                                                                                                                                                                                     zolo  \
# album               name                  artist         release_date album_image_url                                    artist_image_url                                   id
# To Pimp A Butterfly Wesley's Theory       Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 7Ks4VCY1wFebnOdJrM13t6   0.0
#                     For Free? - Interlude Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 75izAeHlGuOgA865CFDyIv   0.0
#                     King Kunta            Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 0N3W5peJUQtI4eyR6GJT5O   0.0
#
#                                                                                                                                                                                                     unknown  \
# album               name                  artist         release_date album_image_url                                    artist_image_url                                   id
# To Pimp A Butterfly Wesley's Theory       Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 7Ks4VCY1wFebnOdJrM13t6      0.0
#                     For Free? - Interlude Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 75izAeHlGuOgA865CFDyIv      0.0
#                     King Kunta            Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 0N3W5peJUQtI4eyR6GJT5O      0.0
#
#                                                                                                                                                                                                     duration_minutes  \
# album               name                  artist         release_date album_image_url                                    artist_image_url                                   id
# To Pimp A Butterfly Wesley's Theory       Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 7Ks4VCY1wFebnOdJrM13t6          4.789333
#                     For Free? - Interlude Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 75izAeHlGuOgA865CFDyIv          2.181550
#                     King Kunta            Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 0N3W5peJUQtI4eyR6GJT5O          3.911550
#
#                                                                                                                                                                                                     tatums_per_minute  \
# album               name                  artist         release_date album_image_url                                    artist_image_url                                   id
# To Pimp A Butterfly Wesley's Theory       Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 7Ks4VCY1wFebnOdJrM13t6         227.589087
#                     For Free? - Interlude Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 75izAeHlGuOgA865CFDyIv         256.698219
#                     King Kunta            Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 0N3W5peJUQtI4eyR6GJT5O         213.726017
#
#                                                                                                                                                                                                     beats_per_minute  \
# album               name                  artist         release_date album_image_url                                    artist_image_url                                   id
# To Pimp A Butterfly Wesley's Theory       Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 7Ks4VCY1wFebnOdJrM13t6        113.794543
#                     For Free? - Interlude Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 75izAeHlGuOgA865CFDyIv        128.349110
#                     King Kunta            Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 0N3W5peJUQtI4eyR6GJT5O        106.863008
#
#                                                                                                                                                                                                     bars_per_minute
# album               name                  artist         release_date album_image_url                                    artist_image_url                                   id
# To Pimp A Butterfly Wesley's Theory       Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 7Ks4VCY1wFebnOdJrM13t6        28.605234
#                     For Free? - Interlude Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 75izAeHlGuOgA865CFDyIv        32.545667
#                     King Kunta            Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... https://i.scdn.co/image/3a836196bfb341f736c7fe2... 0N3W5peJUQtI4eyR6GJT5O        26.332272
#
# [3 rows x 621 columns]

# %%
from sklearn.metrics.pairwise import cosine_distances, cosine_similarity, euclidean_distances, pairwise_distances
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from src.get_data import *
import pandas as pd
import numpy as np
import operator
from collections import Counter
import random
import math
plt.rcParams["axes.grid"] = False


df_mine = pd.read_pickle('../final_num_mine.pkl')
df_2010s = pd.read_pickle('../num_2010s.pkl')
df_rolling = pd.read_pickle('../final_num_rolling.pkl')
df_mega_main = pd.read_pickle('../final_num_all.pkl')

class ItemRecommender():
    '''
    Content based item recommender
    '''
    def __init__(self, similarity_measure=cosine_similarity):
        self.similarity_matrix = None
        self.item_names = None
        self.similarity_measure = similarity_measure

    
    def fit(self, X, scaler=StandardScaler, no_genre=False, just_song=False):
        '''
        Takes a numpy array of the item attributes and creates the similarity matrix

        INPUT -
            X: NUMPY ARRAY - Rows are items, columns are feature values / or DF
            titles: LIST - List of the item names/titles in order of the numpy arrray
        
        OUTPUT - None


        Notes:  You might want to keep titles and X as attributes to refer to them later

        Create a similarity matrix of item to item similarity
        '''

        # While keeping this as a sparse matrix would be best the cosign sim
        # function returns a array so there is no reason.

        lst_of_albums = X.index.get_level_values(1)
        
        if no_genre == True:
            X = X[X.columns[:24] | X.columns[-4:]]
            if just_song == True:
                X.drop(columns=['artist_popularity', 'followers', 'popularity', 'track_number', 'year'],
                            inplace=True)

        scaler = scaler()
        scale_matrix = scaler.fit_transform(X)

        indices = pd.Series(lst_of_albums)

        count_df = pd.DataFrame(scale_matrix, index=indices.values)

        self.item_counts = X
        self.item_names = X.index
        self.similarity_df = pd.DataFrame(self.similarity_measure(count_df.values, count_df.values),
                index = self.item_names)

        
    def get_recommendations(self, song_name, artist_name, n=5, no_genre=False, just_song=False):
        '''
        Returns the top n items related to the item passed in
        INPUT:
            item    - STRING - Name of item in the original DataFrame 
            n       - INT    - Number of top related items to return 
        OUTPUT:
            items - List of the top n related item names

        For a given item find the n most similar items to it (this can be done using the similarity matrix created in the fit method)
        '''
        # Searches for song through Spotipy and then gets variables for the output
        song_df = get_song(song_name, artist_name)

        print(f'You chose {song_df.index[0][1]} by {song_df.index[0][2]} for your song', '\n')
        img = Image.open(requests.get(song_df.index[0][4], stream=True).raw)
        plt.imshow(img)
        plt.axis('off')
        plt.show()
        
        if no_genre == True or just_song == True:
            song_df = song_df[song_df.columns[:23] | song_df.columns[-4:]]
            if just_song == True:
                song_df.drop(columns=['artist_popularity', 'followers', 'popularity', 
                                             'track_number', 'year'],
                            inplace=True)

        simsim = cosine_similarity(song_df, self.item_counts)

        recs_arr = np.argsort(simsim, axis=1)[0][-(n+1):-1]

        for idx, i in enumerate(recs_arr, start=1):
            ser = self.item_counts.iloc[[i], :]
            
            if idx == 1:
                df_recs = pd.DataFrame(ser)
                
            df_recs = df_recs.append(pd.DataFrame(ser))
        
        recs = df_recs.reset_index()
        
        print(f'The most similar {n} songs are displayed below:')
        
        fig = plt.figure(figsize=(10,14))
        ax = []
        columns = 4
        rows = math.ceil(n / columns)
        
        for i in range(n):
            # Captures image to be printed by MatPlotLib at the end of the loop
            img = Image.open(requests.get(recs['album_image_url'].values[i], stream=True).raw)
            ax.append(fig.add_subplot(rows, columns, i+1))
            title = (f'Song Name: {recs["name"][i]}\n Artist Name: {recs["artist"][i]}\n Album Name: {recs["album"][i]}')
            ax[-1].set_title(title, fontsize=6)
            ax[-1].set_axis_off()
            plt.imshow(img)
        
        
        plt.tight_layout()
        plt.show()

        artist_rec = max(Counter(recs['artist']).items(), key=operator.itemgetter(np.random.randint(1)))[0]

        print('\n', f'Artist Recommendation: {artist_rec}', '\n')
        
        plt.imshow(Image.open(requests.get(recs[recs['artist'] == artist_rec]['artist_image_url'].values[0], stream=True).raw))
        plt.axis('off')
        plt.show()

        return df_recs

# %%
test_rec = ItemRecommender()
test_rec.fit(df_mega_main, no_genre=True, just_song=True)
# Out:
# /home/luke/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:50: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead
# /home/luke/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4315: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
n = 20
recs = test_rec.get_recommendations('None Shall Pass', 'Aesop Rock', n=n, no_genre=True, just_song=True)
# Out:
# You chose None Shall Pass by Aesop Rock for your song
# /home/luke/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:89: FutureWarning: Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-099c86b8d727> in <module>
#       1 n = 20
# ----> 2 recs = test_rec.get_recommendations('None Shall Pass', 'Aesop Rock', n=n, no_genre=True, just_song=True)
#
# <ipython-input-11-bff37a7c8a33> in get_recommendations(self, song_name, artist_name, n, no_genre, just_song)
#      93                             inplace=True)
#      94
# ---> 95         simsim = cosine_similarity(song_df, self.item_counts)
#      96
#      97         recs_arr = np.argsort(simsim, axis=1)[0][-(n+1):-1]
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py in cosine_similarity(X, Y, dense_output)
#    1178     # to avoid recursive import
#    1179
# -> 1180     X, Y = check_pairwise_arrays(X, Y)
#    1181
#    1182     X_normalized = normalize(X, copy=True)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py in check_pairwise_arrays(X, Y, precomputed, dtype, accept_sparse, force_all_finite, copy)
#     160         raise ValueError("Incompatible dimension for X and Y matrices: "
#     161                          "X.shape[1] == %d while Y.shape[1] == %d" % (
# --> 162                              X.shape[1], Y.shape[1]))
#     163
#     164     return X, Y
#
# ValueError: Incompatible dimension for X and Y matrices: X.shape[1] == 22 while Y.shape[1] == 23

# %%
recs = recs.reset_index()
recs

# %%
random.choice(range(3))

# %%
multipleartist_rec = max(Counter(recs['artist']).items(), key=operator.itemgetter(0))[0]
artist_rec

# %%
plt.imshow(Image.open(requests.get(recs[recs['artist'] == artist_rec]['album_image_url'].values[0], stream=True).raw))
plt.show()
