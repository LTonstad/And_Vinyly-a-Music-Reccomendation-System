# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics.pairwise import paired_distances
from sklearn.metrics import jaccard_score, pairwise_distances
from sklearn.preprocessing import MinMaxScaler, StandardScaler

from src.recommender import ItemRecommender
from src.get_data import *
from src.data_prep import *

import re

# %%
num_mine = pd.read_pickle('../num_mine.pkl')
num_2010s = pd.read_pickle('../num_2010s.pkl')
num_rolling = pd.read_pickle('../num_rolling.pkl')
num_mega_main = pd.read_pickle('../num_mega_main.pkl')

# %%
print(f'My shape is {num_mine.shape}', '\n')
print(f'Rolling shape is {num_rolling.shape}', '\n')
print(f'2010s shape is {num_2010s.shape}', '\n')
print(f'Mega_Mains shape is {num_mega_main.shape}', '\n')
# Out:
# My shape is (1106, 617)
#
# Rolling shape is (1342, 617)
#
# 2010s shape is (10167, 617)
#
# Mega_Mains shape is (12017, 617)

# %%
song_index = 1

# Items to be output by recommender
album_name = num_mega_main.index[song_index][0]
song_name = num_mega_main.index[song_index][1]
artist_name = num_mega_main.index[song_index][2]
release_date = num_mega_main.index[song_index][3]
album_art_url = num_mega_main.index[song_index][4]
song_id = num_mega_main.index[song_index][5]

# Returns all rows under album_name
df_album = num_mega_main.loc[[album_name]]

# %%
# Creates a set of all albums
lst_of_albums = num_mega_main.index.get_level_values(1)

scaler = StandardScaler()
scale_matrix = scaler.fit_transform(num_mega_main.values)

indices = pd.Series(lst_of_albums)

# %%
rec = ItemRecommender()
count_df = pd.DataFrame(scale_matrix, index=indices.values)

rec.fit(count_df)

# %%
rec.similarity_df.sum(axis=1)
# Out:
# Wesley's Theory          259.872705
# For Free? - Interlude    412.765463
# King Kunta               449.212076
# Institutionalized        156.698746
# These Walls              290.097276
#                             ...
# Loud Pipes              -299.574769
# Kennedy                 -290.451152
# Swisha                  -294.731701
# Nostrand                -304.126448
# Tacobel Canon           -298.487847
# Length: 12017, dtype: float64

# %%
num_mega_main.head(3)
# Out:
#                                                                                                                                                  year  \
# album               name                  artist         release_date album_image_url                                    id
# To Pimp A Butterfly Wesley's Theory       Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... 7Ks4VCY1wFebnOdJrM13t6  2015
#                     For Free? - Interlude Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... 75izAeHlGuOgA865CFDyIv  2015
#                     King Kunta            Kendrick Lamar 2015-03-16   https://i.scdn.co/image/ab67616d0000b273cdb6454... 0N3W5peJUQtI4eyR6GJT5O  2015
#
#                                                                                                                                                  artist_popularity  \
# ...

# %%
album_df = user_input('Demon Days', 'Gorillaz')
album_df
# Out:
# Getting songs for Demon Days
#
# Intro
# Last Living Souls
# Kids with Guns
# O Green World
# Dirty Harry
# Feel Good Inc.
# El Mañana
# Every Planet We Reach Is Dead
# November Has Come
# All Alone
# White Light
# DARE
# Fire Coming out of the Monkey's Head
# Unable to find song :(
# Demon Days
#
# Done getting songs for Demon Days
# /home/luke/galvanize/capstones/DSI_Capstone_Three/src/data_prep.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[genre][i] = 1
#                                                                                                                                                  year  \
# album      name                                 artist   release_date album_image_url                                    id
# ...

# %%
mega_cols = num_mega_main.columns.to_list()
search_cols = album_df.columns.to_list()

# %%
d = {}
outliers = []

for i in mega_cols:
    d[i] = 1
    
for i in search_cols:
    if i in d:
        d[i] += 1
    else:
        print(f'Column {i} is not in MEGA, but is in SEARCH')
        outliers.append(i)

# %%
#add_genre_vals_alt(album_df, df_genre)

# %%
print(rec.get_recommendations(album_df))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-5f7a2bbbcf9c> in <module>()
# ----> 1 print(rec.get_recommendations(album_df))
#
# /home/luke/galvanize/capstones/DSI_Capstone_Three/src/recommender.py in get_recommendations(self, item, n)
#      55         For a given item find the n most similar items to it (this can be done using the similarity matrix created in the fit method)
#      56         '''
# ---> 57         return self.item_names[self.similarity_df.loc[item].values.argsort()[-(n+1):-1]].values[::-1]
#      58
#      59
#
# /home/luke/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# ...
