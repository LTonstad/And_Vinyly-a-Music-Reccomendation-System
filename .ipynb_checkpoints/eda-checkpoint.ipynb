# %%
from src.recommender import *

# %%
print(f'My shape is {df_mine.shape}', '\n')
print(f'Rolling shape is {df_rolling.shape}', '\n')
print(f'Mega_Mains shape is {df_mega_main.shape}', '\n')
print(f'grouped_mine shape is {grouped_mine.shape}', '\n')
print(f'grouped_all shape is {grouped_all.shape}', '\n')
# Out:
# My shape is (1109, 620)
#
# Rolling shape is (1363, 620)
#
# Mega_Mains shape is (22472, 27)
#
# grouped_mine shape is (88, 620)
#
# grouped_all shape is (2026, 27)

# %%
nocl = pd.read_pickle('../final_num_mine.pkl')
nocl
# Out:
#                                                                                                                                                                                                                                           year  \
# album                       name                                               artist          release_date album_image_url                                    artist_image_url                                   id
# The Saga Continues          Wu-Tang The Saga Continues Intro (feat. RZA)       Wu-Tang Clan    2017-10-13   https://i.scdn.co/image/ab67616d0000b2730801dc9... https://i.scdn.co/image/c4014e4323f08d1a32d63c6... 2EsC5nxXhoMrOsYbt59VUM  2017
#                             Lesson Learn'd (feat. Inspectah Deck and Redman)   Wu-Tang Clan    2017-10-13   https://i.scdn.co/image/ab67616d0000b2730801dc9... https://i.scdn.co/image/c4014e4323f08d1a32d63c6... 2RQ47bAanXMoCKIIUn5Kxn  2017
# ...

# %%
new_df = nocl.select_dtypes(include=np.number)
new_df = new_df[grouped_all.columns]
new_df
# Out:
#                                                                                                                                                                                                                                           acousticness  \
# album                       name                                               artist          release_date album_image_url                                    artist_image_url                                   id
# The Saga Continues          Wu-Tang The Saga Continues Intro (feat. RZA)       Wu-Tang Clan    2017-10-13   https://i.scdn.co/image/ab67616d0000b2730801dc9... https://i.scdn.co/image/c4014e4323f08d1a32d63c6... 2EsC5nxXhoMrOsYbt59VUM      0.018200
#                             Lesson Learn'd (feat. Inspectah Deck and Redman)   Wu-Tang Clan    2017-10-13   https://i.scdn.co/image/ab67616d0000b2730801dc9... https://i.scdn.co/image/c4014e4323f08d1a32d63c6... 2RQ47bAanXMoCKIIUn5Kxn      0.000621
# ...

# %% [markdown]
# # Clustering My Vinyls

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.pipeline import Pipeline

import matplotlib.cm as cm
import seaborn as sns

# %%
cluster_pipeline = Pipeline([('scaler', StandardScaler()), ('kmeans', KMeans(n_clusters=10, n_jobs=-1))])

X = new_df.select_dtypes(np.number)
cluster_pipeline.fit(X)
new_df['cluster'] = cluster_pipeline.predict(X)
# Out:
# /home/luke/anaconda3/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py:793: FutureWarning:
#
# 'n_jobs' was deprecated in version 0.23 and will be removed in 1.0 (renaming of 0.25).

# %% [markdown]
# # PCA Visuals

# %%
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split, cross_val_predict, cross_val_score, cross_validate
from sklearn.inspection import permutation_importance

from scipy.stats import spearmanr
from scipy.cluster import hierarchy

# %%
X = new_df

scaler = StandardScaler()
scaler.fit(X)
scaled = scaler.transform(X)
scaled
# Out:
# array([[-7.66108138e-01, -2.59772745e-01, -1.19655953e+00, ...,
#          8.69526395e-01, -1.40854167e+00, -3.62850411e-01],
#        [-8.32319845e-01, -2.59772745e-01, -8.70570191e-01, ...,
#          8.69526395e-01, -2.12855395e-01, -7.65654321e-01],
#        [-8.26221844e-01, -2.59772745e-01, -5.93579426e-01, ...,
#          8.69526395e-01, -2.36437694e-03, -3.62850411e-01],
#        ...,
#        [-2.01883001e-01, -8.46964921e-02, -7.84890201e-01, ...,
#          5.63737661e-01,  9.65675715e-01, -7.65654321e-01],
#        [ 1.24822833e+00, -8.46964921e-02, -1.09057202e+00, ...,
#          5.63737661e-01,  3.45764451e-01,  8.45561319e-01],
#        [ 2.60417659e+00, -8.46964921e-02,  2.40875128e+00, ...,
#          5.63737661e-01, -1.25552743e+00,  8.45561319e-01]])

# %%
pca = PCA()
pca.fit(scaled)
cumsum = np.cumsum(pca.explained_variance_ratio_)
d = np.argmax(cumsum >= 0.95) + 1

# %%
d
# Out:
# 19

# %%
pca = PCA(n_components=d)
pca.fit(scaled)
cumsum = np.cumsum(pca.explained_variance_ratio_)
d = np.argmax(cumsum >= 0.95) + 1
d
# Out:
# 19

# %%
result = permutation_importance(pca, scaled, y=None,n_repeats=10)
perm_sorted_idx = result.importances_mean.argsort()

tree_importance_sorted_idx = np.argsort(pca.explained_variance_ratio_)
tree_indices = np.arange(0, len(pca.explained_variance_ratio_)) + 0.5

fig, ax = plt.subplots(figsize=(12, 8))
ax.barh(tree_indices,
         pca.explained_variance_ratio_[tree_importance_sorted_idx], height=0.7)
ax.set_yticklabels(new_df.columns[tree_importance_sorted_idx])
ax.set_yticks(tree_indices)
ax.set_ylim((0, len(pca.explained_variance_ratio_)))

fig.tight_layout()
plt.title('Permutation Feature Importances (All Songs) After PCA')
plt.show()
#plt.savefig('images/pca_feature_importance_mine.png');
# Out:
# /home/luke/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator

# %%
pca_reduced = new_df[new_df.columns[tree_importance_sorted_idx]]
pca_reduced
# Out:
#                                                                                                                                                                                                                                           start_fade_out  \
# album                       name                                               artist          release_date album_image_url                                    artist_image_url                                   id
# The Saga Continues          Wu-Tang The Saga Continues Intro (feat. RZA)       Wu-Tang Clan    2017-10-13   https://i.scdn.co/image/ab67616d0000b2730801dc9... https://i.scdn.co/image/c4014e4323f08d1a32d63c6... 2EsC5nxXhoMrOsYbt59VUM        86.68009
#                             Lesson Learn'd (feat. Inspectah Deck and Redman)   Wu-Tang Clan    2017-10-13   https://i.scdn.co/image/ab67616d0000b2730801dc9... https://i.scdn.co/image/c4014e4323f08d1a32d63c6... 2RQ47bAanXMoCKIIUn5Kxn       195.45396
# ...

# %% [markdown]
# ## Lets try Clustering again with the reduced dimensions

# %%
cluster_pipeline = Pipeline([('scaler', StandardScaler()), ('kmeans', KMeans(n_clusters=10, n_jobs=-1))])

X = pca_reduced
cluster_pipeline.fit(X)
pca_reduced['cluster'] = cluster_pipeline.predict(X)
# Out:
# /home/luke/anaconda3/lib/python3.7/site-packages/sklearn/cluster/_kmeans.py:793: FutureWarning:
#
# 'n_jobs' was deprecated in version 0.23 and will be removed in 1.0 (renaming of 0.25).
#
# /home/luke/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
pca_reduced
# Out:
#                                                                                                                                                                                                                                           start_fade_out  \
# album                       name                                               artist          release_date album_image_url                                    artist_image_url                                   id
# The Saga Continues          Wu-Tang The Saga Continues Intro (feat. RZA)       Wu-Tang Clan    2017-10-13   https://i.scdn.co/image/ab67616d0000b2730801dc9... https://i.scdn.co/image/c4014e4323f08d1a32d63c6... 2EsC5nxXhoMrOsYbt59VUM        86.68009
#                             Lesson Learn'd (feat. Inspectah Deck and Redman)   Wu-Tang Clan    2017-10-13   https://i.scdn.co/image/ab67616d0000b2730801dc9... https://i.scdn.co/image/c4014e4323f08d1a32d63c6... 2RQ47bAanXMoCKIIUn5Kxn       195.45396
# ...

# %% [markdown]
# ## Checking out correlation matrix to identify best features to showcase in 3D plot

# %%
corrs = pca_reduced.corr()
corrs
# Out:
#                      start_fade_out  speechiness  popularity      mode  \
# start_fade_out             1.000000    -0.139512    0.201328  0.000477
# speechiness               -0.139512     1.000000   -0.146704 -0.057067
# popularity                 0.201328    -0.146704    1.000000 -0.004336
# mode                       0.000477    -0.057067   -0.004336  1.000000
# loudness                   0.196252    -0.016692    0.048791 -0.098258
# liveness                  -0.061600     0.220363   -0.109324 -0.010857
# key                       -0.033873     0.002729   -0.019201 -0.190404
# instrumentalness          -0.082011    -0.211950    0.019989 -0.013808
# has_featured_artist             NaN          NaN         NaN       NaN
# followers                  0.069682    -0.013792    0.350752  0.023993
# explicit                  -0.024300     0.530927    0.029992 -0.134036
# energy                     0.065641     0.050491   -0.035815 -0.044972
# ...

# %%
mask = np.zeros_like(corrs)

mask[np.triu_indices_from(mask)] = True

with sns.axes_style("white"):

    f, ax = plt.subplots(figsize=(14, 14))

    ax = sns.heatmap(corrs, mask=mask, vmax=.3, square=True, cmap='coolwarm')

plt.title('Feature Correlations HeatMap')
#plt.savefig('images/heatmap_mine.png')
# Out:
# Text(0.5, 1.0, 'Feature Correlations HeatMap')

# %% [markdown]
# ## Pulling out the index for the Plotly plot

# %%
import plotly.express as px
import chart_studio
import chart_studio.plotly as py
import chart_studio.tools as tls



tls.set_credentials_file(username=username, api_key=api_key)

# %%
pca_reduced = pca_reduced[pca_reduced['beats_per_minute'] > 50]
pca_reduced
# Out:
#                                                                                                                                                                                                                                           start_fade_out  \
# album                       name                                               artist          release_date album_image_url                                    artist_image_url                                   id
# The Saga Continues          Wu-Tang The Saga Continues Intro (feat. RZA)       Wu-Tang Clan    2017-10-13   https://i.scdn.co/image/ab67616d0000b2730801dc9... https://i.scdn.co/image/c4014e4323f08d1a32d63c6... 2EsC5nxXhoMrOsYbt59VUM        86.68009
#                             Lesson Learn'd (feat. Inspectah Deck and Redman)   Wu-Tang Clan    2017-10-13   https://i.scdn.co/image/ab67616d0000b2730801dc9... https://i.scdn.co/image/c4014e4323f08d1a32d63c6... 2RQ47bAanXMoCKIIUn5Kxn       195.45396
# ...

# %%
newnew = pca_reduced.reset_index()
newnew
# Out:
#                             album  \
# 0              The Saga Continues
# 1              The Saga Continues
# 2              The Saga Continues
# 3              The Saga Continues
# 4              The Saga Continues
# ...                           ...
# 1098  Modern Vampires of the City
# 1099  Modern Vampires of the City
# 1100  Modern Vampires of the City
# 1101  Modern Vampires of the City
# 1102  Modern Vampires of the City
#
#                                                    name           artist  \
# 0          Wu-Tang The Saga Continues Intro (feat. RZA)     Wu-Tang Clan
# 1      Lesson Learn'd (feat. Inspectah Deck and Redman)     Wu-Tang Clan
# 2          Fast and Furious (feat. Hue Hef and Raekwon)     Wu-Tang Clan
# 3                                Famous Fighters (Skit)     Wu-Tang Clan
# 4     If Time Is Money (Fly Navigation) [feat. Metho...     Wu-Tang Clan
# ...                                                 ...              ...
# ...

# %%
newnew['explicit'] = newnew['explicit'].round()

# %% [markdown]
# ## Awesome, now let's actually make the super cool plot

# %%
fig = px.scatter_3d(newnew, x='acousticness', y='beats_per_minute', z='artist_popularity',
              color='cluster', size='liveness',
              symbol='explicit', opacity=0.7, hover_data=['album', 'name', 'artist', 'release_date'])

# tight layout
fig.update_layout(margin=dict(l=0, r=0, b=0, t=0),
                 coloraxis_colorbar=dict(yanchor="top", y=1, x=0,
                                          ticks="outside",
                                          ticksuffix=" Cluster"))
# Out:
# <div>                            <div id="aacc6432-fa99-4b06-9059-4fa1b6e21a3b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aacc6432-fa99-4b06-9059-4fa1b6e21a3b")) {                    Plotly.newPlot(                        "aacc6432-fa99-4b06-9059-4fa1b6e21a3b",                        [{"customdata": [["The Saga Continues", "Wu-Tang The Saga Continues Intro (feat. RZA)", "Wu-Tang Clan", "2017-10-13"], ["The Saga Continues", "Lesson Learn'd (feat. Inspectah Deck and Redman)", "Wu-Tang Clan", "2017-10-13"], ["The Saga Continues", "Fast and Furious (feat. Hue Hef and Raekwon)", "Wu-Tang Clan", "2017-10-13"], ["The Saga Continues", "Famous Fighters (Skit)", "Wu-Tang Clan", "2017-10-13"], ["The Saga Continues", "If Time Is Money (Fly Navigation) [fe
# ...

# %%
#py.plot(fig, filename='My Songs 3D Plot')
# Out:
# 'https://plotly.com/~ltonstad/7/'

# %%
pca_reduced = pca_reduced.reset_index()
pca_reduced
# Out:
#                             album  \
# 0              The Saga Continues
# 1              The Saga Continues
# 2              The Saga Continues
# 3              The Saga Continues
# 4              The Saga Continues
# ...                           ...
# 1098  Modern Vampires of the City
# 1099  Modern Vampires of the City
# 1100  Modern Vampires of the City
# 1101  Modern Vampires of the City
# 1102  Modern Vampires of the City
#
#                                                    name           artist  \
# 0          Wu-Tang The Saga Continues Intro (feat. RZA)     Wu-Tang Clan
# 1      Lesson Learn'd (feat. Inspectah Deck and Redman)     Wu-Tang Clan
# 2          Fast and Furious (feat. Hue Hef and Raekwon)     Wu-Tang Clan
# 3                                Famous Fighters (Skit)     Wu-Tang Clan
# 4     If Time Is Money (Fly Navigation) [feat. Metho...     Wu-Tang Clan
# ...                                                 ...              ...
# ...

# %%
grouped = pca_reduced.groupby(level=['album', 'artist', 'album_image_url', 'artist_image_url']).agg(np.mean)

# %%
X = pca_reduced

scaler = StandardScaler()
scaler.fit(X)
scaled = scaler.transform(X)
scaled
# Out:
# array([[-1.43858133,  1.59551249, -0.90252399, ..., -0.25803816,
#         -0.7642411 ,  0.43151638],
#        [-0.2362151 ,  0.39826562,  0.01010619, ..., -0.25803816,
#         -0.83069265,  0.43151638],
#        [-0.0055337 , -0.20035781, -0.77214825, ..., -0.25803816,
#         -0.82457256,  0.43151638],
#        ...,
#        [ 1.00279065, -0.69833357,  0.33604554, ..., -0.08326623,
#         -0.19797217,  0.80688118],
#        [ 0.39256005, -0.69636009, -0.31583316, ..., -0.08326623,
#          1.25739191, -1.44530763],
#        [-1.3343737 , -0.78450903, -0.31583316, ..., -0.08326623,
#          2.61825182, -1.44530763]])

# %%
lst_of_albums = pca_reduced.index.values
indices = pd.Series(lst_of_albums)

scaled_df = pd.DataFrame(pca_reduced.values, index=indices.values, columns=pca_reduced.columns.values)
scaled_df
# Out:
#                                                     start_fade_out  \
# (The Saga Continues, Wu-Tang The Saga Continues...        86.68009
# (The Saga Continues, Lesson Learn'd (feat. Insp...       195.45396
# (The Saga Continues, Fast and Furious (feat. Hu...       216.32290
# (The Saga Continues, Famous Fighters (Skit), Wu...        80.60680
# (The Saga Continues, If Time Is Money (Fly Navi...       225.11746
# ...                                                            ...
# (Modern Vampires of the City, Finger Back, Vamp...       203.29651
# (Modern Vampires of the City, Worship You, Vamp...       197.65405
# (Modern Vampires of the City, Ya Hey, Vampire W...       307.54248
# (Modern Vampires of the City, Hudson, Vampire W...       252.33705
# (Modern Vampires of the City, Young Lion, Vampi...        96.10739
#
#                                                     speechiness  popularity  \
# (The Saga Continues, Wu-Tang The Saga Continues...       0.4020        32.0
# ...

# %%
#scaled_df.to_pickle('../all_pca_grouped_albums_scaled.pkl')

# %%
#pca_reduced = pca_reduced.drop('cluster', axis=1)

# %%
#scaled_df.to_pickle('../pca_all_no_cluster.pkl')

# %%
grouped = grouped.drop('cluster', axis=1)
grouped
# Out:
#                                                                                                                                                                      start_fade_out  \
# album                                       artist            album_image_url                                    artist_image_url
# 10 Day                                      Chance the Rapper https://i.scdn.co/image/ab67616d0000b2734bbc300... https://i.scdn.co/image/5eb8a2168ab01111c702073...      214.653322
# 1989                                        Taylor Swift      https://i.scdn.co/image/ab67616d0000b273c79b600... https://i.scdn.co/image/8389f45cac7a58e3ab67a3b...      213.123458
# 1989 (Deluxe Edition)                       Taylor Swift      https://i.scdn.co/image/ab67616d0000b273332d855... https://i.scdn.co/image/8389f45cac7a58e3ab67a3b...      227.843482
# ...

# %%
newgr = grouped.reset_index()
newgr
# Out:
#                                           album             artist  \
# 0                                        10 Day  Chance the Rapper
# 1                                          1989       Taylor Swift
# 2                         1989 (Deluxe Edition)       Taylor Swift
# 3                                      Acid Rap  Chance the Rapper
# 4                               An Awesome Wave              alt-J
# ..                                          ...                ...
# 82  You Can't Imagine How Much Fun We're Having         Atmosphere
# 83              You Gotta Go There To Come Back      Stereophonics
# 84                                    blink-182          blink-182
# 85                                    blink-182          blink-182
# 86                                           ye         Kanye West
#
#                                       album_image_url  \
# 0   https://i.scdn.co/image/ab67616d0000b2734bbc30...
# ...

# %%
newgr.groupby(level=['album', 'artist', 'album_image_url', 'artist_image_url'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-42df78563f7c> in <module>
# ----> 1 newgr.groupby(level=['album', 'artist', 'album_image_url', 'artist_image_url'])
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6725             squeeze=squeeze,
#    6726             observed=observed,
# -> 6727             dropna=dropna,
#    6728         )
#    6729
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     566                 observed=observed,
#     567                 mutated=self.mutated,
# --> 568                 dropna=self.dropna,
#     569             )
#     570
#
# ...

# %%
grouped.to_pickle('../pca_mine_no_cluster.pkl')

# %%
lst = []
for col in df_2010s.columns:
    if col not in df_mine.columns:
        lst.append(col)
        
lst
